# %%
import pandas as pd

# %%
user_df = pd.read_csv("../PENS/train.tsv", delimiter='\t', engine='python')

# %%
user_df
# Out:
#          UserID                                        ClicknewsID  \
# 0       U335175  N41340 N27570 N83288 N100653 N105490 N88971 N5...
# 1       U146053  N95202 N84319 N43563 N78688 N94858 N60541 N109...
# 2       U158889  N104156 N103864 N51305 N109347 N70019 N106791 ...
# 3        U22232  N25386 N35729 N32113 N102243 N62352 N22227 N10...
# 4        U32515  N55509 N15992 N27093 N78610 N13691 N103166 N11...
# ...         ...                                                ...
# 399995  U199504  N43145 N54943 N60556 N13448 N37007 N93865 N940...
# 399996  U236246  N37463 N53716 N84319 N20284 N20362 N117490 N10...
# 399997  U318251  N52505 N87652 N118791 N15107 N95202 N77690 N21...
# 399998  U215323  N47207 N15248 N62450 N47961 N13818 N90850 N100...
# 399999  U119029                              N83606 N91273 N118951
#
#                                                 dwelltime  \
# 0       116 23 59 146 661 303 59 199 165 144 110 29 32...
# ...

# %%
summ_df = pd.read_csv("../datasets/summ.csv")

# %%
summ_df
# Out:
#          SummID   NewsID   UserID  \
# 0            S1   N24324  U335175
# 1            S2   N93272  U335175
# 2            S3   N43563  U146053
# 3            S4   N97393  U146053
# 4            S5  N104663  U146053
# ...         ...      ...      ...
# 777529  S777530   N51965  U215323
# 777530  S777531   N49096  U215323
# 777531  S777532   N44501  U215323
# 777532  S777533   N59444  U215323
# 777533  S777534   N81907  U215323
#
#                                                   Summary
# 0       Heat Wave Is Going to Hit Europe, Prepare to C...
# 1       Everything you need to know to plan your dream...
# 2       Baby Boomers Love City Life as Much As Millenials
# 3       Piping plover forces Sandy Hook to cancel all ...
# 4       Trip Advisor's Guide to Eating America: for th...
# ...                                                   ...
# 777529     Ranking Penguin's possible picks for NHL draft
# 777530                    Homeland Still Exposed to ISIS
# ...

# %%
synthetic_original_df = pd.read_csv("../datasets/synthetic-original.csv")

# %%
synthetic_original_df
# Out:
#          UserID                                               Docs  \
# 0       U335175  ['N41340', 'N55476', 'N103556', 'N27570', 'N83...
# 1       U146053  ['N95202', 'N84319', 'N92854', 'N43563', 'S3',...
# 2       U158889  ['N84182', 'N72110', 'N122127', 'N24095', 'N96...
# 3        U22232  ['N25386', 'N90820', 'N35729', 'N32113', 'N444...
# 4        U32515  ['N55509', 'N111634', 'N15992', 'N78883', 'N27...
# ...         ...                                                ...
# 399989  U199504  ['N43145', 'N93930', 'N28736', 'N52394', 'N549...
# 399990  U236246  ['N37463', 'N53716', 'N84319', 'N20284', 'N224...
# 399991  U318251  ['N91695', 'N38780', 'N78552', 'N52505', 'N876...
# 399992  U215323  ['N47207', 'N15248', 'N50002', 'N62450', 'N479...
# 399993  U119029  ['N79723', 'N74784', 'N67437', 'N53379', 'N123...
#
#                                                    Action  Summaries
# 0       ['click', 'click', 'click', 'click', 'click', ...          2
# ...

# %% [markdown]
# **We'll refine the synthetic original by removing rows that contain a 0 summary node.**

# %%
synthetic_modified_df = pd.read_csv("../datasets/synthetic-modified.csv")

# %%
synthetic_modified_df
# Out:
#          UserID                                               Docs  \
# 0       U335175  ['N41340', 'N55476', 'N103556', 'N27570', 'N83...
# 1       U146053  ['N95202', 'N84319', 'N92854', 'N43563', 'S3',...
# 2        U22232  ['N25386', 'N90820', 'N35729', 'N32113', 'N444...
# 3        U32515  ['N55509', 'N111634', 'N15992', 'N78883', 'N27...
# 4       U260848  ['N113658', 'N58081', 'N99270', 'N60159', 'N55...
# ...         ...                                                ...
# 250551   U68615  ['N70520', 'N118951', 'N71699', 'N90982', 'N36...
# 250552  U199504  ['N43145', 'N93930', 'N28736', 'N52394', 'N549...
# 250553  U236246  ['N37463', 'N53716', 'N84319', 'N20284', 'N224...
# 250554  U318251  ['N91695', 'N38780', 'N78552', 'N52505', 'N876...
# 250555  U215323  ['N47207', 'N15248', 'N50002', 'N62450', 'N479...
#
#                                                    Action  Summaries
# 0       ['click', 'click', 'click', 'click', 'click', ...          2
# ...

# %% [markdown]
# ## Augmented Dataset (Source Dataset: `synthetic-original.csv`)

# %%
synthetic_augmented_df = pd.read_csv("../datasets/synthetic-original-augmented.csv")

# %%
synthetic_augmented_df
# Out:
#          UserID                                               Docs  \
# 0       U335175  ['N41340', 'N55476', 'N103556', 'N27570', 'N83...
# 1       U158889  ['N84182', 'N72110', 'N15124', 'N85806', 'N114...
# 2        U22232  ['N25386', 'N90820', 'N49011', 'N80134', 'N684...
# 3        U32515  ['N55509', 'N111634', 'N14872', 'N35463', 'N10...
# 4       U260848  ['N113658', 'N58081', 'N99270', 'N72931', 'N91...
# ...         ...                                                ...
# 399988  U199504  ['N43145', 'N93930', 'N28736', 'N122890', 'N86...
# 399989  U236246  ['N37463', 'N53716', 'N84319', 'N20284', 'N224...
# 399990  U318251  ['N91695', 'N38780', 'N78552', 'N79292', 'N933...
# 399991  U215323  ['N47207', 'N15248', 'N50002', 'N62450', 'N479...
# 399992  U119029  ['N79723', 'N74784', 'N67437', 'N53379', 'N123...
#
#                                                    Action  Summaries
# 0       ['click', 'click', 'click', 'click', 'click', ...          2
# ...

# %%
synthetic_augmented_df[synthetic_augmented_df.Summaries == 2]
# Out:
#          UserID                                               Docs  \
# 0       U335175  ['N41340', 'N55476', 'N103556', 'N27570', 'N83...
# 3        U32515  ['N55509', 'N111634', 'N14872', 'N35463', 'N10...
# 6       U187822  ['N74784', 'N113294', 'N67437', 'N53379', 'N90...
# 8       U155201  ['N54160', 'N84182', 'N59937', 'N84004', 'N103...
# 9       U285976  ['N83606', 'N123225', 'S17', 'N61154', 'N85806...
# ...         ...                                                ...
# 399975   U86922  ['N65742', 'N119172', 'N17103', 'N98034', 'N83...
# 399977  U117328  ['N81048', 'N36682', 'N85471', 'N30427', 'N696...
# 399984   U85458  ['N90558', 'N55055', 'N87184', 'N78688', 'N134...
# 399987   U68615  ['N70520', 'N118951', 'N71699', 'N21789', 'N17...
# 399989  U236246  ['N37463', 'N53716', 'N84319', 'N20284', 'N224...
#
#                                                    Action  Summaries
# 0       ['click', 'click', 'click', 'click', 'click', ...          2
# ...

# %%
synthetic_augmented_df.iloc[1]['Action']
# Out:
# "['skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'click', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'click', 'click', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'click', 'click', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'click', 'skip', 'skip', 'click', 'skip', 'skip', 'skip', 'skip', 'skip', 'skip', 'click', 'skip', 'skip', 'skip', 'click', 'skip', 'click', 'skip', 'skip', 'skip']"

# %%
# df = synthetic_augmented_df.drop(synthetic_augmented_df.index[1])
# df.to_csv("../datasets/synthetic-original-augmented.csv", index=False)
